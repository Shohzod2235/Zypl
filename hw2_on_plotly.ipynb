# %% [markdown]
# # Домашнее задание №
#
# **исполнитель: Shohzod Masrabov**
#
# ## Задача 1
#
# ### Описание задачи
# Полное описание задачи.
#
# ### Решение
# ```python

# %%
import pandas as pd
import plotly.express as px

# Пример данных (замените на реальные данные из вашей базы данных):
# SQL-запрос:
# SELECT billing_country, continent, SUM(total) AS total_sales, COUNT(track_id) AS total_tracks
# FROM invoice i
# JOIN customer c ON i.customer_id = c.customer_id
# JOIN track t ON t.track_id = i.track_id
# GROUP BY billing_country, continent;

data = {
    "billing_country": ["USA", "Canada", "Germany", "France", "Japan", "India"],
    "continent": ["North America", "North America", "Europe", "Europe", "Asia", "Asia"],
    "total_sales": [5000, 3000, 2000, 2500, 1500, 1200],
    "total_tracks": [100, 80, 60, 70, 50, 40]
}

# Создание датафрейма
df = pd.DataFrame(data)

# Настройка цветов для континентов
continent_colors = {
    "Asia": "yellow",
    "Europe": "blue",
    "North America": "red"
}

# Построение scatter plot
fig = px.scatter(
    df,
    x="total_tracks",
    y="total_sales",
    color="continent",
    color_discrete_map=continent_colors,
    title="Соотношение суммы продаж и количества треков"
)

# Кастомизация графика
fig.update_layout(
    title_font=dict(size=30, color="gray"),  # Настройки шрифта заголовка
    xaxis_title="Количество треков",
    yaxis_title="Сумма продаж",
    xaxis=dict(
        tickfont=dict(size=14, color="gray")  # Настройки шрифта для оси X
    ),
    yaxis=dict(
        tickfont=dict(size=14, color="gray")  # Настройки шрифта для оси Y
    )
)

# Отображение диаграммы
fig.show()

# %%
# Создание датафрейма
df = pd.DataFrame(data)

# Настройка цветов: серый для всех жанров, цвета для Jazz, Rock, и Alternative & Punk
bar_colors = []
for genre in df["genre_name"]:
    if genre == "Jazz":import pandas as pd
import plotly.graph_objects as go

# Пример данных (замените на реальные данные из вашей базы данных):
# SQL-запрос:
# SELECT genre_name, COUNT(track_id) AS track_count
# FROM genre g
# JOIN track t ON g.genre_id = t.genre_id
# GROUP BY genre_name;

data = {
    "genre_name": ["Jazz", "Rock", "Alternative & Punk", "Classical", "Pop", "Blues"],
    "track_count": [150, 200, 180, 120, 170, 130]
}

        bar_colors.append("yellow")
    elif genre == "Rock":
        bar_colors.append("blue")
    elif genre == "Alternative & Punk":
        bar_colors.append("red")
    else:
        bar_colors.append("gray")

# Создание столбчатой диаграммы
fig = go.Figure()

fig.add_trace(go.Bar(
    x=df["genre_name"],
    y=df["track_count"],
    marker=dict(color=bar_colors),  # Применение кастомных цветов
    showlegend=False  # Убираем легенду
))

# Настройка стиля графика
fig.update_layout(
    title=dict(
        text="<i>Количество треков по жанрам</i>",  # Название курсивом
        font=dict(size=24),
        x=0.5  # Выравнивание по центру
    ),
    xaxis=dict(
        title="Жанры",
        tickfont=dict(size=14, color="gray")
    ),
    yaxis=dict(
        title="Количество треков",
        tickfont=dict(size=14, color="gray")
    ),
    plot_bgcolor="white"  # Белый фон графика
)

# Отображение диаграммы
fig.show()
